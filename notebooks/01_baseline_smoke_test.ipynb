# %%
import pandas as pd
import sys

# %%
train_dataframe = pd.read_csv("../data/train.csv")
test_dataframe = pd.read_csv("../data/test.csv")

# %%
sys.path.append("../")

# %%
from src.baseline_Smoke_Test import run_majority_baseline

# %%
baseline_smoke_test = run_majority_baseline(train_dataframe, test_dataframe)
# Out:
# The results were saved inside the outputs/Baseline_Smoke_Test folder ✅
